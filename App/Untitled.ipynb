# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Data/data_base.xlsx')
df
# Out:
#                Nombre  Numero Categoria Hora de salida
# 0               Juana      14    Perros       08:29:00
# 1            Carlitos     143    Perros       08:29:00
# 2              Pepito      53    Perros       08:29:00
# 3              Chigüi     141    Perros       08:29:00
# 4             Gabriel      98    Perros       08:29:00
# 5              Pancha     231     Gatos       08:29:00
# 6             Carlota     214     Gatos       08:29:00
# 7       Jesús Antonio      52     Gatos       08:29:00
# 8             Gerarda      15     Gatos       08:29:00
# 9       La virgencita      64     Gatos       08:29:00
# 10            El Gato     241     Gatos       08:29:00
# 11                Alá      86     Gatos       08:29:00
# 12        Bob esponja      45    Chivos       08:29:00
# 13    El hombre araña      36    Chivos       08:29:00
# 14           Gatúbela      32    Chivos       08:29:00
# 15              Nairo      76    Chivos       08:29:00
# ...

# %%
df['Tiempo de llegada'] = np.random.random(18)*100
df
# Out:
#                Nombre  Numero Categoria Hora de salida    Random  \
# 0               Juana      14    Perros       08:29:00  0.507000
# 1            Carlitos     143    Perros       08:29:00  0.713049
# 2              Pepito      53    Perros       08:29:00  0.640768
# 3              Chigüi     141    Perros       08:29:00  0.732708
# 4             Gabriel      98    Perros       08:29:00  0.260181
# 5              Pancha     231     Gatos       08:29:00  0.381620
# 6             Carlota     214     Gatos       08:29:00  0.026678
# 7       Jesús Antonio      52     Gatos       08:29:00  0.472737
# 8             Gerarda      15     Gatos       08:29:00  0.728861
# 9       La virgencita      64     Gatos       08:29:00  0.806586
# 10            El Gato     241     Gatos       08:29:00  0.416820
# 11                Alá      86     Gatos       08:29:00  0.178285
# 12        Bob esponja      45    Chivos       08:29:00  0.985102
# ...

# %%
df.loc[df['Categoria']=='Perros','Tiempo de llegada'].mean()

df.groupby('Categoria')['Tiempo de llegada'].mean()
# Out:
# Categoria
# Chivos    39.559741
# Gatos     53.132524
# Perros    68.201051
# Name: Tiempo de llegada, dtype: float64
